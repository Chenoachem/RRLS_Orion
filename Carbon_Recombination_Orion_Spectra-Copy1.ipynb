# %%
import os
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import sys
import csv
from operator import itemgetter, attrgetter, methodcaller
# %matplotlib inline

# %%
#cd ~/Dropbox/SETI_Orion

# %%
source="G19467"
data = np.genfromtxt('G19467-clean.csv', delimiter=',', skip_header=10,skip_footer=10, names=['x', 'y'])
freq=data['x']
signal=data['y']

# %%
#data=sorted(data, key=itemgetter(0))
#freq, signal = zip(*data)
#with open('freqtest.csv','w')as f:
    #writer = csv.writer(f,delimiter=',')
    #writer.writerows(zip(freq,signal))

# %%
import matplotlib.patches as mpatches
fig, axs = plt.subplots(3, 3, sharex=False, sharey=True)
fig.set_figheight(15)
fig.set_figwidth(15)
#axs[0,0].plot(x)
axs[0,0].step(freq[0:96],signal[0:96],color='blue')
axs[0,0].fill_between(np.arange(ca_lines[0]-0.01,ca_lines[0]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[0,0].fill_between(np.arange(ca_lines[1]-0.01,ca_lines[0]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[0,0].fill_between(np.arange(ca_lines[1]-0.01,ca_lines[1]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[0,0].set_title("Cube 1",fontsize=18)
#axs[0,0].set_xlabel("Frequency (MHz)",fontsize=18)
axs[0,0].set_ylim(-1.5,1.5)
axs[0,0].set_xlim(99.3,100.2)
#axs[0,0].set_ylabel("Flux Density (Jy beam$^{-1}$)",fontsize=18)
#axs[0,0].get_xaxis().get_major_formatter().set_useOffset(False)
axs[0,0].tick_params(labelsize=15)
plum_patch = mpatches.Patch(color='plum', label='Carbon Alpha Lines')
axs[0,0].legend(handles=[plum_patch],loc=1)


#axs[0,1]=bigfig.add_subplot(122, sharey=ax1)
axs[0,1].step(freq[106:196],signal[106:196],color='blue')
axs[0,1].fill_between(np.arange(ca_lines[2]-0.01,ca_lines[2]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[0,1].set_title("Cube 2",fontsize=18)
#axs[0,1].set_xlabel("Frequency (MHz)",fontsize=18)
axs[0,1].set_ylim(-1.5,1.5)
axs[0,1].set_xlim(100.7,101.7)
#axs[0,1].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
#axs[0,1].get_xaxis().get_major_formatter().set_useOffset(False)
#axs[0,1].xaxis.set_major_formatter(majorFormatter)
axs[0,1].tick_params(labelsize=15)
green_patch = mpatches.Patch(color='mediumspringgreen', label='Carbon Beta Lines')
axs[0,1].legend(handles=[green_patch],loc=1)

#axs[1,0]=bigfig.add_subplot(221, sharey=ax1)
axs[0,2].step(freq[206:296],signal[206:296],color='blue')
axs[0,2].fill_between(np.arange(ca_lines[4]-0.01,ca_lines[4]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[0,2].set_title("Cube 3",fontsize=18)
#axs[0,2].set_xlabel("Frequency (MHz)",fontsize=18)
axs[0,2].set_ylim(-1.5,1.5)
axs[0,2].set_xlim(102.0,103.0)
#axs[1,0].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
#axs[0,2].get_xaxis().get_major_formatter().set_useOffset(False)
axs[0,2].tick_params(labelsize=15)

#axs[1,1]=bigfig.add_subplot(222, sharey=ax1)
axs[1,0].step(freq[306:396],signal[306:396],color='blue')
axs[1,0].fill_between(np.arange(ca_lines[6]-0.01,ca_lines[6]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[1,0].set_title("Cube 4",fontsize=18)
axs[1,0].set_ylabel("Flux Density (Jy beam$^{-1}$)",fontsize=18)
#axs[1,0].set_xlabel("Frequency (MHz)",fontsize=18)
axs[1,0].set_ylim(-1.5,1.5)
axs[1,0].set_xlim(103.2,104.2)
#axs[1,0].get_xaxis().get_major_formatter().set_useOffset(False)
#axs[1,1].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
axs[1,0].tick_params(labelsize=15)

axs[1,1].step(freq[406:496],signal[406:496],color='blue')
axs[1,1].fill_between(np.arange(ca_lines[7]-0.01,ca_lines[7]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[1,1].fill_between(np.arange(cb_lines[1]-0.01,cb_lines[1]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[1,1].set_title("Cube 5",fontsize=18)
#axs[1,1].set_xlabel("Frequency (MHz)",fontsize=18)
axs[1,1].set_ylim(-1.5,1.5)
axs[1,1].set_xlim(104.5,105.5)
axs[1,1].get_xaxis().get_major_formatter().set_useOffset(False)
#axs[1,1].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
axs[1,1].tick_params(labelsize=15)

axs[1,2].step(freq[506:596],signal[506:596],color='blue')
axs[1,2].fill_between(np.arange(ca_lines[8]-0.01,ca_lines[8]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[1,2].fill_between(np.arange(ca_lines[9]-0.01,ca_lines[9]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[1,2].fill_between(np.arange(cb_lines[3]-0.01,cb_lines[3]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[1,2].set_title("Cube 6",fontsize=18)
#axs[1,2].set_xlabel("Frequency (MHz)",fontsize=18)
axs[1,2].set_ylim(-1.5,1.5)
axs[1,2].set_xlim(105.8,106.8)
#axs[1,2].get_xaxis().get_major_formatter().set_useOffset(False)
#axs[1,1].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
axs[1,2].tick_params(labelsize=15)

axs[2,0].step(freq[602:696],signal[602:696],color='blue')
axs[2,0].fill_between(np.arange(ca_lines[11]-0.01,ca_lines[11]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[2,0].fill_between(np.arange(cb_lines[5]-0.01,cb_lines[5]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[2,0].fill_between(np.arange(cb_lines[6]-0.01,cb_lines[6]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[2,0].set_title("Cube 7",fontsize=18)
#axs[2,0].set_xlabel("Frequency (MHz)",fontsize=18)
axs[2,0].set_ylim(-1.5,1.5)
axs[2,0].set_xlim(107.1,108.1)
#axs[2,0].get_xaxis().get_major_formatter().set_useOffset(False)
#axs[1,1].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
axs[2,0].tick_params(labelsize=15)
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)

axs[2,1].step(freq[701:801],signal[701:801],color='blue')
axs[2,1].fill_between(np.arange(ca_lines[12]-0.01,ca_lines[12]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[2,1].fill_between(np.arange(cb_lines[7]-0.01,cb_lines[7]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[2,1].fill_between(np.arange(cb_lines[8]-0.01,cb_lines[8]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[2,1].set_title("Cube 8",fontsize=18)
axs[2,1].set_xlabel("Frequency (MHz)",fontsize=18)
axs[2,1].set_ylim(-1.5,1.5)
axs[2,1].set_xlim(108.3,109.3)
#axs[2,1].get_xaxis().get_major_formatter().set_useOffset(False)
#axs[1,1].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
axs[2,1].tick_params(labelsize=15)

axs[2,2].step(freq[806:896],signal[806:896],color='blue')
axs[2,2].fill_between(np.arange(ca_lines[13]-0.01,ca_lines[13]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[2,2].fill_between(np.arange(ca_lines[11]-0.01,ca_lines[11]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[2,2].fill_between(np.arange(cb_lines[9]-0.01,cb_lines[9]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[2,2].fill_between(np.arange(cb_lines[10]-0.01,cb_lines[10]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[2,2].set_title("Cube 9",fontsize=18)
#axs[2,2].set_xlabel("Frequency (MHz)",fontsize=18)
axs[2,2].set_ylim(-1.5,1.5)
axs[2,2].set_xlim(109.5,110.5)
#axs[2,2].get_xaxis().get_major_formatter().set_useOffset(False)
#axs[1,1].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
axs[2,2].tick_params(labelsize=15)

plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)

fig.savefig(source+'-Part1_marked.png', pad_inches=0.5,bbox_inches='tight')

# %%
ca_lines=[99.41,100.151,100.899,101.655,102.419,103.19,103.968,104.755,105.55,106.352,107.163,107.982,108.81,109.646,110.49,111.343,
          112.205,113.076,113.956,114.845,115.744,116.652,117.569,118.496,119.433,120.379,121.336,122.303,123.28,124.267,125.265,
          126.274,127.294,128.325]

# %%
cb_lines=[104.018,104.642,105.271,105.905,106.544,107.189,107.838,108.493,109.154,109.819,110.49,111.167,111.849,112.536,
          113.229,113.928,114.633,115.344,116.06,116.782,117.511,118.245,118.986,119.733,120.486,121.245,122.011,122.783,123.562,
          124.347,125.139,125.938,126.743,127.556,128.375]

# %%
fig, axs = plt.subplots(3, 3, sharex=False, sharey=True)
fig.set_figheight(15)
fig.set_figwidth(15)
#axs[0,0].plot(x)
axs[0,0].step(freq[1007:1095],signal[1007:1095],color='blue')
axs[0,0].fill_between(np.arange(ca_lines[15]-0.01,ca_lines[15]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[0,0].fill_between(np.arange(cb_lines[7]-0.01,cb_lines[7]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[0,0].fill_between(np.arange(cb_lines[8]-0.01,cb_lines[8]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[0,0].set_title("Cube 10",fontsize=18)
#axs[0,0].set_xlabel("Frequency (MHz)",fontsize=18)
axs[0,0].set_ylim(-1.5,1.5)
axs[0,0].set_xlim(110.8,111.8)
#axs[0,0].set_ylabel("Flux Density (Jy beam$^{-1}$)",fontsize=18)
axs[0,0].get_xaxis().get_major_formatter().set_useOffset(False)
axs[0,0].tick_params(labelsize=15)
plum_patch = mpatches.Patch(color='plum', label='Carbon Alpha Lines')
axs[0,0].legend(handles=[plum_patch],loc=1)

#axs[0,1]=bigfig.add_subplot(122, sharey=ax1)
axs[0,1].step(freq[1091:1195],signal[1091:1195],color='blue')
axs[0,1].fill_between(np.arange(ca_lines[16]-0.01,ca_lines[16]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[0,1].fill_between(np.arange(cb_lines[13]-0.01,cb_lines[13]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[0,1].fill_between(np.arange(cb_lines[14]-0.01,cb_lines[14]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[0,1].set_title("Cube 11",fontsize=18)
#axs[0,1].set_xlabel("Frequency (MHz)",fontsize=18)
axs[0,1].set_ylim(-1.5,1.5)
axs[0,1].set_xlim(112.1,113.1)
#axs[0,1].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
axs[0,1].get_xaxis().get_major_formatter().set_useOffset(False)
#axs[0,1].xaxis.set_major_formatter(majorFormatter)
axs[0,1].tick_params(labelsize=15)
green_patch = mpatches.Patch(color='mediumspringgreen', label='Carbon Beta Lines')
axs[0,1].legend(handles=[green_patch],loc=1)

#axs[1,0]=bigfig.add_subplot(221, sharey=ax1)
axs[0,2].step(freq[1206:1296],signal[1206:1296],color='blue')
axs[0,2].fill_between(np.arange(ca_lines[18]-0.01,ca_lines[18]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[0,2].fill_between(np.arange(cb_lines[15]-0.01,cb_lines[15]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[0,2].set_title("Cube 12",fontsize=18)
#axs[0,2].set_xlabel("Frequency (MHz)",fontsize=18)
axs[0,2].set_ylim(-1.5,1.5)
axs[0,2].set_xlim(113.4,114.4)
#axs[1,0].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
axs[0,2].get_xaxis().get_major_formatter().set_useOffset(False)
axs[0,2].tick_params(labelsize=15)

#axs[1,1]=bigfig.add_subplot(222, sharey=ax1)
axs[1,0].step(freq[1306:1395],signal[1306:1395],color='blue')
axs[1,0].fill_between(np.arange(ca_lines[19]-0.01,ca_lines[19]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[1,0].fill_between(np.arange(cb_lines[11]-0.01,cb_lines[11]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[1,0].set_title("Cube 13",fontsize=18)
#axs[1,0].set_xlabel("Frequency (MHz)",fontsize=18)
axs[1,0].set_ylim(-1.5,1.5)
axs[1,0].set_ylabel("Flux Density (Jy beam$^{-1}$)",fontsize=18)
axs[1,0].set_xlim(114.7,115.7)
axs[1,0].get_xaxis().get_major_formatter().set_useOffset(False)
#axs[1,1].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
axs[1,0].tick_params(labelsize=15)

axs[1,1].step(freq[1407:1493],signal[1407:1493],color='blue')
axs[1,1].fill_between(np.arange(ca_lines[22]-0.01,ca_lines[22]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[1,1].fill_between(np.arange(ca_lines[17]-0.01,ca_lines[17]+0.01,0.01), -1.5, 1.5, facecolor='blue', alpha=0.5)
axs[1,1].fill_between(np.arange(cb_lines[20]-0.01,cb_lines[20]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[1,1].set_title("Cube 14",fontsize=18)
#axs[1,1].set_xlabel("Frequency (MHz)",fontsize=18)
axs[1,1].set_ylim(-1.5,1.5)
axs[1,1].set_xlim(117.2,118.2)
axs[1,1].get_xaxis().get_major_formatter().set_useOffset(False)
#axs[1,1].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
axs[1,1].tick_params(labelsize=15)

axs[1,2].step(freq[1506:1595],signal[1506:1595],color='blue')
axs[1,2].fill_between(np.arange(ca_lines[16]-0.01,ca_lines[16]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[1,2].fill_between(np.arange(cb_lines[22]-0.01,cb_lines[22]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[1,2].set_title("Cube 15",fontsize=18)
#axs[1,2].set_xlabel("Frequency (MHz)",fontsize=18)
axs[1,2].set_ylim(-1.5,1.5)
axs[1,2].set_xlim(118.5,119.5)
axs[1,2].get_xaxis().get_major_formatter().set_useOffset(False)
#axs[1,1].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
axs[1,2].tick_params(labelsize=15)

axs[2,0].step(freq[1606:1695],signal[1606:1695],color='blue')
axs[2,0].fill_between(np.arange(ca_lines[25]-0.01,ca_lines[25]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[2,0].fill_between(np.arange(cb_lines[24]-0.01,cb_lines[24]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[2,0].set_title("Cube 16",fontsize=18)
#axs[2,0].set_xlabel("Frequency (MHz)",fontsize=18)
axs[2,0].set_ylim(-1.5,1.5)
axs[2,0].set_xlim(119.8,120.8)
axs[2,0].get_xaxis().get_major_formatter().set_useOffset(False)
#axs[1,1].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
axs[2,0].tick_params(labelsize=15)
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)

axs[2,1].step(freq[1709:1795],signal[1709:1795],color='blue')
axs[2,1].fill_between(np.arange(ca_lines[25]-0.01,ca_lines[25]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[2,1].fill_between(np.arange(ca_lines[26]-0.01,ca_lines[26]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[2,1].fill_between(np.arange(cb_lines[25]-0.01,cb_lines[25]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[2,1].fill_between(np.arange(cb_lines[26]-0.01,cb_lines[26]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[2,1].set_title("Cube 17",fontsize=18)
axs[2,1].set_xlabel("Frequency (MHz)",fontsize=18)
axs[2,1].set_ylim(-1.5,1.5)
axs[2,1].set_xlim(121.0,121.9)
axs[2,1].get_xaxis().get_major_formatter().set_useOffset(False)
#axs[1,1].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
axs[2,1].tick_params(labelsize=15)

axs[2,2].step(freq[1798:1898],signal[1798:1898],color='blue')
axs[2,2].fill_between(np.arange(ca_lines[25]-0.01,ca_lines[25]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[2,2].fill_between(np.arange(ca_lines[26]-0.01,ca_lines[26]+0.01,0.01), -1.5, 1.5, facecolor='plum', alpha=0.5)
axs[2,2].fill_between(np.arange(cb_lines[25]-0.01,cb_lines[25]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[2,2].fill_between(np.arange(cb_lines[26]-0.01,cb_lines[26]+0.01,0.01), -1.5, 1.5, facecolor='mediumspringgreen', alpha=0.5)
axs[2,2].set_title("Cube 18",fontsize=18)
#axs[2,2].set_xlabel("Frequency (MHz)",fontsize=18)
axs[2,2].set_ylim(-1.5,1.5)
axs[2,2].set_xlim(122.0,122.9)
axs[2,2].get_xaxis().get_major_formatter().set_useOffset(False)
#axs[1,1].set_ylabel("Flux Density (Jy/beam)",fontsize=18)
axs[2,2].tick_params(labelsize=15)

plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1.0)

fig.savefig(source+'-Part2_marked.png', pad_inches=0.5,bbox_inches='tight')
